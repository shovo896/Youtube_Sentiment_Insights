# %%
# %%bash
# set -a
# if [ -f .env ]; then
#   . .env
# elif [ -f ../.env ]; then
#   . ../.env
# fi
# set +a
#
# aws configure set aws_access_key_id "$aws_access_key"
# aws configure set aws_secret_access_key "$aws_secret_access_key"
# aws configure set default.region us-east-1
# aws configure set default.output json
# aws configure list
# Out:
#       Name                    Value             Type    Location
#       ----                    -----             ----    --------
#    profile                <not set>             None    None
# access_key     ****************EUHG shared-credentials-file
# secret_key     ****************dglh shared-credentials-file
#     region                us-east-1      config-file    ~/.aws/config

# %%
import mlflow
print("MLflow Version:", mlflow.__version__)

mlflow.set_tracking_uri("http://13.220.34.174:5000")

print("Tracking URI:", mlflow.get_tracking_uri())
# Out:
# MLflow Version: 3.13.0
# Tracking URI: http://13.220.34.174:5000

# %%
# Set or create an experiment
mlflow.set_experiment("Exp 5 - ML Algos with HP Tuning")
# Out:
# 2026/06/01 20:54:21 INFO mlflow.tracking.fluent: Experiment with name 'Exp 5 - ML Algos with HP Tuning' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://mlflow-bucket-28/7', creation_time=1780325662027, effective_trace_archival_retention=None, experiment_id='7', last_update_time=1780325662027, lifecycle_stage='active', name='Exp 5 - ML Algos with HP Tuning', tags={}, trace_location=None, workspace='default'>

# %%
! pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: alembic>=1.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (1.16.4)
# Collecting colorlog (from optuna)
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (2.0.39)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.13/site-packages (from alembic>=1.5.0->optuna) (1.2.3)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/anaconda3/lib/python3.13/site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/lib/python3.13/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
# Using cached colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [optuna]2m1/2 [optuna]
# Successfully installed colorlog-6.10.1 optuna-4.9.0
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import optuna
import mlflow
import mlflow.sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[7], line 9
#       7 from sklearn.linear_model import LogisticRegression
#       8 from sklearn.svm import SVC
# ----> 9 from xgboost import XGBClassifier
#      10 from lightgbm import LGBMClassifier
#      11 from sklearn.neighbors import KNeighborsClassifier
#
# File ~/.local/lib/python3.13/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)
#      15     build_info,
#      16 )
#
# File ~/.local/lib/python3.13/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, _deprecate_positional_args, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/.local/lib/python3.13/site-packages/xgboost/core.py:309
#     305     return lib
#     308 # load the XGBoost library globally
# --> 309 _LIB = _load_lib()
#     312 def _check_call(ret: int) -> None:
#     313     """Check the return value of C API call
#     314
#     315     This function will raise exception when error occurs.
#    (...)
#     321         return value from API calls
#     322     """
#
# File ~/.local/lib/python3.13/site-packages/xgboost/core.py:273, in _load_lib()
#     271     if not lib_success:
#     272         libname = os.path.basename(lib_paths[0])
# --> 273         raise XGBoostError(f"""
#     274 XGBoost Library ({libname}) could not be loaded.
#     275 Likely causes:
#     276   * OpenMP runtime is not installed
#     277     - vcomp140.dll or libgomp-1.dll for Windows
#     278     - libomp.dylib for Mac OSX
#     279     - libgomp.so for Linux and other UNIX-like OSes
#     280     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     281
#     282   * You are running 32-bit Python on a 64-bit OS
#     283
#     284 Error message(s): {os_error_list}
#     285 """)
#     286     _register_log_callback(lib)
#     288     libver = _lib_version(lib)
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ['dlopen(/Users/imac/.local/lib/python3.13/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Symbol not found: ___kmpc_dispatch_deinit\n  Referenced from: <5A4ADBF3-2060-3ECB-AB2B-F8A248DDA0A7> /Users/imac/.local/lib/python3.13/site-packages/xgboost/lib/libxgboost.dylib\n  Expected in:     <8AE74FFC-75EE-374B-BA46-A70944EA81BD> /opt/anaconda3/lib/libomp.dylib']
